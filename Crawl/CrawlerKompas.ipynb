# %%
import re
import mechanize
import os
import sys
import urllib.request

# %%
br = mechanize.Browser()
linklist=[]
kamus={}
values = 1
count = 0

day = 1
dayend = 31
mounth = 4
year = 2019
tahun = year
bulan = mounth
tanggal = day
halstart = 1
halend = 30

# %%
print("Start to execute...")
for tanggal in range(tanggal, dayend):
    print("Crawling data on:", tahun,"/", bulan,"/", tanggal, "|Page", halstart,"-", halend-1)
    i=1
    for i in range(halstart, halend):
        #print("Include page", i)
        if tanggal <10:
            if bulan <10:
                r = br.open("https://news.kompas.com/search/"+ str(tahun)+ "-0" + str(bulan)+ "-0"+ str(tanggal) + "/"+ str(i))
            else:
                r = br.open("https://news.kompas.com/search/"+ str(tahun)+ "-" + str(bulan)+ "-0"+ str(tanggal) +"/"+ str(i))
        else:
            if bulan <10:
                r = br.open("https://news.kompas.com/search/"+ str(tahun)+ "-0" + str(bulan)+ "-"+ str(tanggal) + "/"+ str(i))
            else:
                r = br.open("https://news.kompas.com/search/"+ str(tahun)+ "-" + str(bulan)+ "-"+ str(tanggal) + "/"+ str(i))

        for link in br.links():
            linklist.append(link.url)

        for links in linklist:
            if links not in kamus and re.search(r"/read/",links):
                kamus[links]=values
                count+=1
                #print(kamus[links])
            else:
                pass
print("Executed successfully")
# Out:
# Start to execute...
# Crawling data on: 2019 / 4 / 1 |Page 1 - 29
# Crawling data on: 2019 / 4 / 2 |Page 1 - 29
# Crawling data on: 2019 / 4 / 3 |Page 1 - 29
# Crawling data on: 2019 / 4 / 4 |Page 1 - 29
# Crawling data on: 2019 / 4 / 5 |Page 1 - 29
# Crawling data on: 2019 / 4 / 6 |Page 1 - 29
# Crawling data on: 2019 / 4 / 7 |Page 1 - 29
# Crawling data on: 2019 / 4 / 8 |Page 1 - 29
# Crawling data on: 2019 / 4 / 9 |Page 1 - 29
# Crawling data on: 2019 / 4 / 10 |Page 1 - 29
# Crawling data on: 2019 / 4 / 11 |Page 1 - 29
# Crawling data on: 2019 / 4 / 12 |Page 1 - 29
# Crawling data on: 2019 / 4 / 13 |Page 1 - 29
# Crawling data on: 2019 / 4 / 14 |Page 1 - 29
# Crawling data on: 2019 / 4 / 15 |Page 1 - 29
# Crawling data on: 2019 / 4 / 16 |Page 1 - 29
# Crawling data on: 2019 / 4 / 17 |Page 1 - 29
# Crawling data on: 2019 / 4 / 18 |Page 1 - 29
# Crawling data on: 2019 / 4 / 19 |Page 1 - 29
# Crawling data on: 2019 / 4 / 20 |Page 1 - 29
# Crawling data on: 2019 / 4 / 21 |Page 1 - 29
# ...

# %%
print(kamus)
# Out:
# ati-may-day': 1, 'https://megapolitan.kompas.com/read/2019/04/30/15353191/panduan-jalan-kaki-dari-stasiun-sudirman-ke-mrt-dukuh-atas': 1, 'https://nasional.kompas.com/read/2019/04/30/15290821/wapres-kalla-perbatasan-zee-indonesia-vietnam-masih-dirundingkan': 1, 'https://internasional.kompas.com/read/2019/04/30/15283041/christchurch-digegerkan-temuan-bom-dan-amunisi-di-lahan-kosong': 1, 'https://regional.kompas.com/read/2019/04/30/15271601/mensos-santuni-korban-meninggal-dunia-banjir-dan-longsor-bengkulu': 1, 'https://regional.kompas.com/read/2019/04/30/15243251/bupati-talaud-ditangkap-kpk-partai-hanura-belum-ambil-sikap': 1, 'https://regional.kompas.com/read/2019/04/30/15241871/lebaran-ada-wahana-benteng-takeshi-dan-banana-boat-di-kompleks-jakabaring': 1, 'https://nasional.kompas.com/read/2019/04/30/15241801/kata-wapres-kalla-cita-cita-pemindahan-ibu-kota-seperti-new-york-dan': 1, 'https://regional.kompas.com/read/2019/04/30/15205441/meski-berbahaya-mobil-bak-terbuka-di-kendal-tetap-
# ...

# %%
f = open("dataKompas.txt","w")
for x in kamus:
    f.write(x + "\n")
f.close()

# %%
f = open("dataKompas.txt","r")
count = 3945

for link in f:
    print(link)
    urllib.request.urlretrieve(link, "Kompas-" + str(count) + ".html")
    count+=1
    print("\nDownloading file: ", count)
print("Finish : ", count)
f.close()
# Out:
# 11/bikin-macet-jalanan-732-pedagang-pasar-kampung-lalang-diminta-tempati-kios
#
#
# ...
# https://internasional.kompas.com/read/2019/04/02/17424431/senjata-ak-buatan-rusia-atau-china-mana-yang-lebih-baik
#
#
# ...
# https://regional.kompas.com/read/2019/04/02/17384501/jika-menang-pilpres-prabowo-janji-turunkan-tarif-listrik-100-hari-masa
#
#
# ...
# https://megapolitan.kompas.com/read/2019/04/02/17380391/anies-minta-penumpang-mrt-berlatih-simpan-sampahnya
#
#
# ...
# https://nasional.kompas.com/read/2019/04/02/17333861/balques-manisang-dan-tomy-ristanto-ditunjuk-sebagai-moderator-debat-kelima
#
#
# ...
# https://regional.kompas.com/read/2019/04/02/17310131/warga-di-salah-satu-desa-di-batam-bentangkan-spanduk-bertuliskan-terima
#
#
# ...
# https://regional.kompas.com/read/2019/04/02/17292651/alasan-hakim-hukum-berat-dua-begal-sadis-pemotong-tangan-di-makassar
#
#
# ...
# https://nasional.kompas.com/read/2019/04/02/17283911/maruf-amin-dulu-memang-pak-jokowi-kalah-di-ntb-sekarang-tidak
#
#
# ...
